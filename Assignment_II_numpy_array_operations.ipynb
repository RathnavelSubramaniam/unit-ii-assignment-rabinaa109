# %% [markdown]
# > ### **Assignment 2 - Numpy Array Operations**
# >
#
#
# Write a short introduction about Numpy and list the chosen functions.
#
# function1 = np.append
#
# function2 = np.average
#
# function3 = np.arange
#
# function4 = np.squeeze
#
# function5 = np.vstack

# %%
import numpy as np

# %% [markdown]
# ## Function 1 - np.append
# np.append function add elements to the end of an array provided that the dimensions of the elements should be same.

# %%
# Example 1 - working (change this)
arr1 = [1, 2, 1, 25, 26]
np.append(arr1, [24, 23, 15])
# Out:
# array([ 1,  2,  1, 25, 26, 24, 23, 15])

# %% [markdown]
# We can put lists as an element inside the array, then append it with the expected lists or any element regardless of their size.

# %%
# Example 2 - working
arr2 = [[2, 4, 5], [6, 7, 8]]
np.append(arr2, [10, 12])
np.append(arr2, [10, 12, 13, 14])
# Out:
# array([ 2,  4,  5,  6,  7,  8, 10, 12, 13, 14])

# %% [markdown]
# When axis is specified, arrays must have the same shape.

# %%
# Example 3 - breaking (to illustrate when it breaks)
arr3 = [[2, 4, 5], [6, 7, 8]]
np.append(arr3, [14, 15, 16], axis = 0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Rabina A\Documents\Python\Unit2\Assignment_II_numpy_array_operations.ipynb Cell 8' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Rabina%20A/Documents/Python/Unit2/Assignment_II_numpy_array_operations.ipynb#ch0000007?line=0'>1</a> # Example 3 - breaking (to illustrate when it breaks)
#       <a href='vscode-notebook-cell:/c%3A/Users/Rabina%20A/Documents/Python/Unit2/Assignment_II_numpy_array_operations.ipynb#ch0000007?line=1'>2</a> arr3 = [[2, 4, 5], [6, 7, 8]]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Rabina%20A/Documents/Python/Unit2/Assignment_II_numpy_array_operations.ipynb#ch0000007?line=2'>3</a> np.append(arr3, [14, 15, 16], axis = 0)
#
# File <__array_function__ internals>:180, in append(*args, **kwargs)
#
# File c:\Users\Rabina A\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\lib\function_base.py:5392, in append(arr, values, axis)
#    <a href='file:///c%3A/Users/Rabina%20A/AppData/Local/Programs/Python/Python310/lib/site-packages/numpy/lib/function_base.py?line=5389'>5390</a>     values = ravel(values)
#    <a href='file:///c%3A/Users/Rabina%20A/AppData/Local/Programs/Python/Python310/lib/site-packages/numpy/lib/function_base.py?line=5390'>5391</a>     axis = arr.ndim-1
# -> <a href='file:///c%3A/Users/Rabina%20A/AppData/Local/Programs/Python/Python310/lib/site-packages/numpy/lib/function_base.py?line=5391'>5392</a> return concatenate((arr, values), axis=axis)
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 2 dimension(s) and the array at index 1 has 1 dimension(s)

# %% [markdown]
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 2 dimension(s) and the array at index 1 has 1 dimension(s)

# %% [markdown]
# Some closing comments about when to use this function.

# %%
# Fix
arr3 = [[2, 4, 5], [6, 7, 8]]
np.append(arr3, [[14, 15, 16], [12, 15, 16]], axis = 0)
# Out:
# array([[ 2,  4,  5],
#        [ 6,  7,  8],
#        [14, 15, 16],
#        [12, 15, 16]])

# %% [markdown]
# In arr3, index 0 has 2 dimensions, while the element to be appended has 1 dimension, thus breaks down. To fix this, the element to be appended should have 2 dimensions as well.

# %% [markdown]
# ## Function 2 - np.average
#
# Add some explanations

# %%
# Example 1 - working
array1 = [[2, 4, 6], [6, 8, 10], [12, 14, 16]]
np.average(array1)
# Out:
# 8.666666666666666

# %% [markdown]
# Explanation about example

# %%
#Example 2 -working
array2 = [1, 2, 1, 25, 26]
np.average(array2)
# Out:
# 11.0

# %% [markdown]
# Explanation about example

# %%
# Example 3 - breaking (to illustrate when it breaks)
a = [-1, 1, 2, 2]
np.average(a,[1,2,3,4], axis=0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\Rabina A\Downloads\Assignment_II_numpy_array_operations.ipynb Cell 18' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Rabina%20A/Downloads/Assignment_II_numpy_array_operations.ipynb#ch0000017?line=0'>1</a> # Example 3 - breaking (to illustrate when it breaks)
#       <a href='vscode-notebook-cell:/c%3A/Users/Rabina%20A/Downloads/Assignment_II_numpy_array_operations.ipynb#ch0000017?line=1'>2</a> a = [-1, 1, 2, 2]
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Rabina%20A/Downloads/Assignment_II_numpy_array_operations.ipynb#ch0000017?line=2'>3</a> np.average(a,[1,2,3,4], axis=0)
#
# File <__array_function__ internals>:179, in average(*args, **kwargs)
#
# TypeError: _average_dispatcher() got multiple values for argument 'axis'

# %% [markdown]
# Explanation about example (why it breaks and how to fix it)

# %%
a = [-1, 1, 2, 2]
np.average(a)
# Out:
# 1.0

# %% [markdown]
# Some closing comments about when to use this function.

# %% [markdown]
# ## Function 3 - np.arange
#
# Add some explanations

# %%
# Example 1 - working
np.arange(3,7)
# Out:
# array([3, 4, 5, 6])

# %% [markdown]
# Explanation about example

# %%
# Example 2 - working
np.arange(3,7,2)
# Out:
# array([3, 5])

# %% [markdown]
# Explanation about example

# %%
# Example 3 - breaking (to illustrate when it breaks)
np.arange(3,7,int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\kasth\OneDrive\Desktop\Python\Assignments\Unit (2)\Assignment_II_numpy_array_operations.ipynb Cell 27' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/kasth/OneDrive/Desktop/Python/Assignments/Unit%20%282%29/Assignment_II_numpy_array_operations.ipynb#ch0000026?line=0'>1</a> # Example 3 - breaking (to illustrate when it breaks)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kasth/OneDrive/Desktop/Python/Assignments/Unit%20%282%29/Assignment_II_numpy_array_operations.ipynb#ch0000026?line=1'>2</a> np.arange(3,7,int)
#
# TypeError: unsupported operand type(s) for /: 'int' and 'type'

# %% [markdown]
# Explanation about example (why it breaks and how to fix it)

# %%
np.arange(3,7,2,int)

# %% [markdown]
# Some closing comments about when to use this function.

# %% [markdown]
# ## Function 4 - np.squeeze
#
# Add some explanations

# %%
# Example 1 - working
x = np.array([[[0], [1], [2]]])
x.shape
# Out:
# (1, 3, 1)

# %%
np.squeeze(x,axis=0).shape
# Out:
# (3, 1)

# %% [markdown]
# Explanation about example

# %%
# Example 2 - working
x1 = np.array([[[0], [1], [2]]])
x1
# Out:
# array([[[0],
#         [1],
#         [2]]])

# %%
np.squeeze(x1,axis=1).shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\kasth\OneDrive\Desktop\Python\Assignments\Unit (2)\Assignment_II_numpy_array_operations.ipynb Cell 36' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kasth/OneDrive/Desktop/Python/Assignments/Unit%20%282%29/Assignment_II_numpy_array_operations.ipynb#ch0000035?line=0'>1</a> np.squeeze(x1,axis=1).shape
#
# File <__array_function__ internals>:180, in squeeze(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\numpy\core\fromnumeric.py:1545, in squeeze(a, axis)
#    <a href='file:///c%3A/Users/kasth/AppData/Local/Programs/Python/Python310/lib/site-packages/numpy/core/fromnumeric.py?line=1542'>1543</a>     return squeeze()
#    <a href='file:///c%3A/Users/kasth/AppData/Local/Programs/Python/Python310/lib/site-packages/numpy/core/fromnumeric.py?line=1543'>1544</a> else:
# -> <a href='file:///c%3A/Users/kasth/AppData/Local/Programs/Python/Python310/lib/site-packages/numpy/core/fromnumeric.py?line=1544'>1545</a>     return squeeze(axis=axis)
#
# ValueError: cannot select an axis to squeeze out which has size not equal to one

# %% [markdown]
# Explanation about example

# %%
# Example 3 - breaking (to illustrate when it breaks)
x11 = np.array([[[0], [1], [2]]])
x11.shape
# Out:
# (1, 3, 1)

# %%
np.squeeze(x11,axis=1).shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\kasth\OneDrive\Desktop\Python\Assignments\Unit (2)\Assignment_II_numpy_array_operations.ipynb Cell 39' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kasth/OneDrive/Desktop/Python/Assignments/Unit%20%282%29/Assignment_II_numpy_array_operations.ipynb#ch0000038?line=0'>1</a> np.squeeze(x11,axis=1).shape
#
# NameError: name 'x11' is not defined

# %% [markdown]
# Explanation about example (why it breaks and how to fix it)

# %% [markdown]
# Some closing comments about when to use this function.

# %% [markdown]
# ## Function 5 - np.vstack
#
# Add some explanations

# %%
# Example 1 - working
x = np.array([3, 5, 7])
y = np.array([5, 7, 9])
np.vstack((x,y))
# Out:
# array([[3, 5, 7],
#        [5, 7, 9]])

# %% [markdown]
# Explanation about example

# %%
# Example 2 - working
x = np.array([[3], [5], [7]])
y = np.array([[5], [7], [9]])
np.vstack((x,y))
# Out:
# array([[3],
#        [5],
#        [7],
#        [5],
#        [7],
#        [9]])

# %% [markdown]
# Explanation about example

# %%
# Example 3 - breaking (to illustrate when it breaks)
x1 = np.array([[3], [5], [7]])
y1 = np.array([5], [7], [9])
np.vstack((x1,y1))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\kasth\OneDrive\Desktop\Python\Assignments\Unit (2)\Assignment_II_numpy_array_operations.ipynb Cell 47' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/kasth/OneDrive/Desktop/Python/Assignments/Unit%20%282%29/Assignment_II_numpy_array_operations.ipynb#ch0000047?line=0'>1</a> # Example 3 - breaking (to illustrate when it breaks)
#       <a href='vscode-notebook-cell:/c%3A/Users/kasth/OneDrive/Desktop/Python/Assignments/Unit%20%282%29/Assignment_II_numpy_array_operations.ipynb#ch0000047?line=1'>2</a> x1 = np.array([[3], [5], [7]])
# ----> <a href='vscode-notebook-cell:/c%3A/Users/kasth/OneDrive/Desktop/Python/Assignments/Unit%20%282%29/Assignment_II_numpy_array_operations.ipynb#ch0000047?line=2'>3</a> y1 = np.array([5], [7], [9])
#       <a href='vscode-notebook-cell:/c%3A/Users/kasth/OneDrive/Desktop/Python/Assignments/Unit%20%282%29/Assignment_II_numpy_array_operations.ipynb#ch0000047?line=3'>4</a> np.vstack((x1,y1))
#
# TypeError: array() takes from 1 to 2 positional arguments but 3 were given

# %% [markdown]
# Explanation about example (why it breaks and how to fix it)

# %%
x1 = np.array([[3], [5], [7]])
y1 = np.array([[5], [7], [9]])
np.vstack((x1,y1))
# Out:
# array([[3],
#        [5],
#        [7],
#        [5],
#        [7],
#        [9]])

# %% [markdown]
# Some closing comments about when to use this function.

# %%
import numpy as np
import pandas as pd

# %%
#create DataFrame with some NaN values
df = pd.DataFrame({'rating': [np.nan, 85, np.nan, 88, 94, 90, 76, 75, 87, 86],
                   'points': [25, np.nan, 14, 16, 27, 20, 12, 15, 14, 19],
                   'assists': [5, 7, 7, np.nan, 5, 7, 6, 9, 9, 5],
                   'rebounds': [11, 8, 10, 6, 6, 9, 6, 10, 10, 7]})

# %%
df
# Out:
#    rating  points  assists  rebounds
# 0     NaN    25.0      5.0        11
# 1    85.0     NaN      7.0         8
# 2     NaN    14.0      7.0        10
# 3    88.0    16.0      NaN         6
# 4    94.0    27.0      5.0         6
# 5    90.0    20.0      7.0         9
# 6    76.0    12.0      6.0         6
# 7    75.0    15.0      9.0        10
# 8    87.0    14.0      9.0        10
# 9    86.0    19.0      5.0         7

# %%
df['rating'].median()
# Out:
# 86.5

# %%
df['rating'] = df['rating'].fillna(df['rating'].median())

# %%
df
# Out:
#    rating  points  assists  rebounds
# 0    86.5    25.0      5.0        11
# 1    85.0     NaN      7.0         8
# 2    86.5    14.0      7.0        10
# 3    88.0    16.0      NaN         6
# 4    94.0    27.0      5.0         6
# 5    90.0    20.0      7.0         9
# 6    76.0    12.0      6.0         6
# 7    75.0    15.0      9.0        10
# 8    87.0    14.0      9.0        10
# 9    86.0    19.0      5.0         7
